# %%
import pandas as pd

# %%
# reading the csv file
df = pd.read_csv("StudentsPerformance.csv")

# %% [markdown]
# # Selecting one column

# %% [markdown]
# ## Syntax 1

# %%
# select a column with [] (preferred way to select a column)
df["parental level of education"]
# Out:
# 0       bachelor's degree
# 1            some college
# 2         master's degree
# 3      associate's degree
# 4            some college
#               ...
# 995       master's degree
# 996           high school
# 997           high school
# 998          some college
# 999          some college
# Name: parental level of education, Length: 1000, dtype: object

# %%
# check out the data type of a column
type(df["parental level of education"])
# Out:
# pandas.core.series.Series

# %%
# series: attributes and methods
df["parental level of education"].index
df["parental level of education"].info
df["parental level of education"].dtypes
df["parental level of education"].shape
# Out:
# (1000,)

# %% [markdown]
# ## Syntax 2

# %%
# select a column with .
df.gender
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
# select the same column using []
df["math score"]
# Out:
# 0      72
# 1      69
# 2      90
# 3      47
# 4      76
#        ..
# 995    88
# 996    62
# 997    59
# 998    68
# 999    77
# Name: math score, Length: 1000, dtype: int64
